# %%
import zipfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
zip_file = r"C:\Users\91850\Documents\rabiya\prasunet internship\titanic.zip"
with zipfile.ZipFile(zip_file, 'r') as z:
    print(z.namelist())
    for filename in z.namelist():
        print(filename)
# Out:
# ['gender_submission.csv', 'test.csv', 'train.csv']
# gender_submission.csv
# test.csv
# train.csv

# %%
zip_file = r"C:\Users\91850\Documents\rabiya\prasunet internship\titanic.zip"
with zipfile.ZipFile(zip_file, 'r') as z:
    csv_filename = 'train.csv'
    df = pd.read_csv(z.open(csv_filename))
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Display the first few rows of the dataset
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Check for missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Fill missing values
df['Age'].fillna(df['Age'].median(), inplace = True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace = True)

# Drop the 'Cabin' column
df.drop(columns=['Cabin'], inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

# %%
df['Sex'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Embarked'] = df['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
# Summary statistics
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.352413   29.361582
# std     257.353842    0.486592    0.836071    0.477990   13.019697
# min       1.000000    0.000000    1.000000    0.000000    0.420000
# 25%     223.500000    0.000000    2.000000    0.000000   22.000000
# 50%     446.000000    0.000000    3.000000    0.000000   28.000000
# 75%     668.500000    1.000000    3.000000    1.000000   35.000000
# max     891.000000    1.000000    3.000000    1.000000   80.000000
#
#             SibSp       Parch        Fare    Embarked
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208    1.536476
# std      1.102743    0.806057   49.693429    0.791503
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400    1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 76.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare  Embarked
# 0         A/5 21171   7.2500         2
# 1          PC 17599  71.2833         0
# 2  STON/O2. 3101282   7.9250         2
# 3            113803  53.1000         2
# 4            373450   8.0500         2

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Sex   Age  SibSp  Parch      Ticket   Fare  Embarked
# 886    0  27.0      0      0      211536  13.00         2
# 887    1  19.0      0      0      112053  30.00         2
# 888    1  28.0      1      2  W./C. 6607  23.45         2
# 889    0  26.0      0      0      111369  30.00         0
# 890    0  32.0      0      0      370376   7.75         1

# %%
df.shape
# Out:
# (891, 11)

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Embarked']

# %%
#Univariate Analysis
# Age distribution
plt.figure(figsize =(20,10))
sns.histplot(df['Age'], kde=True, color='Red')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Univariate Analysis
#Fare Diatribution
plt.figure(figsize=(20,10))
sns.histplot(df['Fare'], kde=True, color='Red')
plt.title('Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %%
#Univariate Analysis
#Survival Rate
plt.figure(figsize=(20,10))
sns.countplot(x='Survived', data=df, palette='dark')
plt.title('Survival count')
plt.xlabel('Survival')
plt.ylabel('Count')
plt.show()

# %%
#Bivariate Analysis

#Survival by sex
plt.figure(figsize=(20,10))
sns.countplot(x='Survived', hue='Sex', data=df, palette='dark')
plt.title('Survival by sex')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.legend(title='Sex', loc='upper right', labels=['Male', 'Female'])
plt.show()

# %%
#Bivariate Analysis

#Survival by passenger class
plt.figure(figsize=(20,10))
sns.countplot(x='Survived', hue='Pclass', data=df, palette='dark')
plt.title('Survival by passenger class')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.legend(title='Pclass', loc='upper right', labels=['1st', '2nd', '3rd'])
plt.show()

# %%
#Bivariate Analysis

#Age distribution by survival
plt.figure(figsize=(20,10))
sns.countplot(data=df, x='Age', hue='Survived', fill=True, palette='dark')
plt.title('Age distribution by survival')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %%
#Multivariate Analysis

#pairplot
plt.figure(figsize=(20,10))
sns.pairplot(df[['Survived', 'Age', 'Fare', 'Sex', 'Pclass']], hue='Survived', palette='dark')
plt.show()

# %%
#Correlation Matrix
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True, cmap='Blues', linewidths=0.12)
plt.title("Correlation Matrix")
plt.show()

# %%
#Correlation Matrix

#Define Age Groups
bins=[0, 12, 18, 30, 60, 100]
labels=['Child', 'Teenager', 'Young Adult', 'Adult', 'Senior']
df['Age group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Survival by Age group
plt.figure(figsize=(10, 6))
sns.countplot(x='Age group', hue='Survived', data=df, palette='Blues')
plt.title('Survival by Age group')
plt.xlabel('Age group')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#Correlation Matrix

# Number of Survivors
number_survivors=df['Survived'].sum()
number_survivors
# Out:
# 342

# %%
#Correlation Matrix

# Fare of Survivors
fare_survivors = df[df['Survived'] == 1]['Fare']
fare_survivors.describe()
# Out:
# count    342.000000
# mean      48.395408
# std       66.596998
# min        0.000000
# 25%       12.475000
# 50%       26.000000
# 75%       57.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
#Correlation Matrix

# Gender that survived the most 
gender_that_survived = df.groupby('Sex')['Survived'].sum()
gender_that_survived
# Out:
# Sex
# 0    109
# 1    233
# Name: Survived, dtype: int64

# %%
#Correlation Matrix

# Pclass that survived
pclass_that_survived = df.groupby('Pclass')['Survived'].sum()
pclass_that_survived
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64
